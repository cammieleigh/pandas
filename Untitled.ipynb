# %%
import pandas as pd

# %%
df = pd.read_csv('data/new1dictionary.csv')

# %%
df
# Out:
#      Character                              Definition Pinyin Decomposition  \
# 0            ⺀                                     ice    NaN             ？
# 1            ⺈                                     NaN    NaN             ？
# 2            ⺊                                     NaN    NaN           ⿰丨？
# 3            ⺌                                     NaN    NaN             ？
# 4            ⺍                                     NaN    NaN             ？
# ...        ...                                     ...    ...           ...
# 9569         龠             flute; pipe;ancient measure    yuè           ⿱亼？
# 9570         龥                       to beg;to implore     yù           ⿰龠頁
# 9571         龶                                     NaN    NaN             ？
# 9572         龹  Form of 卷 used as a phonetic component   quǎn           ⿻？丿
# 9573         龺           sunlight; the rays of the sun    gān          ⿳十日十
#
#      Radical
# 0          ⺀
# 1          ⺈
# ...

# %%
pd.set_option('display.max_columns', 5)

# %%
df
# Out:
#      Character                              Definition  ... Unnamed: 30  \
# 0            ⺀                                     ice  ...         NaN
# 1            ⺈                                     NaN  ...         NaN
# 2            ⺊                                     NaN  ...         NaN
# 3            ⺌                                     NaN  ...         NaN
# 4            ⺍                                     NaN  ...         NaN
# ...        ...                                     ...  ...         ...
# 9569         龠             flute; pipe;ancient measure  ...         NaN
# 9570         龥                       to beg;to implore  ...         NaN
# 9571         龶                                     NaN  ...         NaN
# 9572         龹  Form of 卷 used as a phonetic component  ...         NaN
# 9573         龺           sunlight; the rays of the sun  ...         NaN
#
#      Unnamed: 31
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
pd.options.display.max_columns = 5

# %%
df
# Out:
#      Character                              Definition  ... Unnamed: 30  \
# 0            ⺀                                     ice  ...         NaN
# 1            ⺈                                     NaN  ...         NaN
# 2            ⺊                                     NaN  ...         NaN
# 3            ⺌                                     NaN  ...         NaN
# 4            ⺍                                     NaN  ...         NaN
# ...        ...                                     ...  ...         ...
# 9569         龠             flute; pipe;ancient measure  ...         NaN
# 9570         龥                       to beg;to implore  ...         NaN
# 9571         龶                                     NaN  ...         NaN
# 9572         龹  Form of 卷 used as a phonetic component  ...         NaN
# 9573         龺           sunlight; the rays of the sun  ...         NaN
#
#      Unnamed: 31
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
pd.options.display.max_columns = 7

# %%
df
# Out:
#      Character                              Definition  pinyin  ...  \
# 0            ⺀                                     ice     NaN  ...
# 1            ⺈                                     NaN     NaN  ...
# 2            ⺊                                     NaN     NaN  ...
# 3            ⺌                                     NaN     NaN  ...
# 4            ⺍                                     NaN     NaN  ...
# ...        ...                                     ...     ...  ...
# 9569         龠             flute; pipe;ancient measure   "yuè"  ...
# 9570         龥                       to beg;to implore    "yù"  ...
# 9571         龶                                     NaN     NaN  ...
# 9572         龹  Form of 卷 used as a phonetic component  "quǎn"  ...
# 9573         龺           sunlight; the rays of the sun   "gān"  ...
#
#      Unnamed: 29 Unnamed: 30 Unnamed: 31
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# ...

# %%
df
# Out:
#      Character                              Definition  pinyin decomposition  \
# 0            ⺀                                     ice     NaN             ？
# 1            ⺈                                     NaN     NaN             ？
# 2            ⺊                                     NaN     NaN           ⿰丨？
# 3            ⺌                                     NaN     NaN             ？
# 4            ⺍                                     NaN     NaN             ？
# ...        ...                                     ...     ...           ...
# 9569         龠             flute; pipe;ancient measure   "yuè"           ⿱亼？
# 9570         龥                       to beg;to implore    "yù"           ⿰龠頁
# 9571         龶                                     NaN     NaN             ？
# 9572         龹  Form of 卷 used as a phonetic component  "quǎn"           ⿻？丿
# 9573         龺           sunlight; the rays of the sun   "gān"          ⿳十日十
#
#      radical
# 0          ⺀
# 1          ⺈
# ...

# %%
df[radical].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df[radical].value_counts()
#
# NameError: name 'radical' is not defined

# %%
df[radical].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[radical].value_counts()
#
# NameError: name 'radical' is not defined

# %%
df["Character"].value_counts()
# Out:
# Character
# ⺀    1
# 荣    1
# 荥    1
# 荦    1
# 荧    1
#     ..
# 朗    1
# 望    1
# 朝    1
# 期    1
# 龺    1
# Name: count, Length: 9574, dtype: int64

# %%
df["radical"].value_counts()
# Out:
# radical
# 氵                                           465
# 口                                           421
# 艹                                           406
# 木                                           382
# 扌                                           341
#                                            ...
# ⺈                                             1
# 歺                                             1
# matches:[[1]                                  1
#  building up steam 丷 and letting it off}      1
# 龶                                             1
# Name: count, Length: 312, dtype: int64

# %%
df["Pinyin"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pinyin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ...

# %%
df["pinyin"].value_counts()
# Out:
# pinyin
# "yì"      79
# "lì"      65
# "xī"      57
# "yù"      56
# "jī"      56
#           ..
# "liāo"     1
# "zuàn"     1
# "shōu"     1
# "gǎi"      1
# "óu"       1
# Name: count, Length: 1240, dtype: int64

# %%
df[“Radical”].value_counts()
# Out:
#   Cell In[1], line 1
#     df[“Radical”].value_counts()
#        ^
# SyntaxError: invalid character '“' (U+201C)

# %%
df["Radical"].value_counts()
# Out:
# Radical
# 氵                                           465
# 口                                           421
# 艹                                           406
# 木                                           382
# 扌                                           341
#                                            ...
# ⺈                                             1
# 歺                                             1
# matches:[[1]                                  1
#  building up steam 丷 and letting it off}      1
# 龶                                             1
# Name: count, Length: 312, dtype: int64

# %%
df["Pinyin"].value_counts()
# Out:
# Pinyin
# "yì"      79
# "lì"      65
# "xī"      57
# "yù"      56
# "jī"      56
#           ..
# "liāo"     1
# "zuàn"     1
# "shōu"     1
# "gǎi"      1
# "óu"       1
# Name: count, Length: 1240, dtype: int64

# %%
series = pd.DataFrame(
    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "radicals"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 series = pd.DataFrame(
# ----> 2     3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "radicals"]
#       3 )
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
series = pd.DataFrame(
    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "radicals"]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36228\2771986701.py in ?()
# ----> 1 series = df.DataFrame(
#       2     3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "radicals"]
#       3 )
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
series.plot.pie(subplots=True, figsize=(8, 4));

# %%
df.plot.pie(subplots=True, figsize=(8, 4));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.plot.pie(subplots=True, figsize=(8, 4))
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
df
# Out:
#      Character                              Definition  Pinyin Decomposition  \
# 0            ⺀                                     ice     NaN             ？
# 1            ⺈                                     NaN     NaN             ？
# 2            ⺊                                     NaN     NaN           ⿰丨？
# 3            ⺌                                     NaN     NaN             ？
# 4            ⺍                                     NaN     NaN             ？
# ...        ...                                     ...     ...           ...
# 9569         龠             flute; pipe;ancient measure   "yuè"           ⿱亼？
# 9570         龥                       to beg;to implore    "yù"           ⿰龠頁
# 9571         龶                                     NaN     NaN             ？
# 9572         龹  Form of 卷 used as a phonetic component  "quǎn"           ⿻？丿
# 9573         龺           sunlight; the rays of the sun   "gān"          ⿳十日十
#
#      Radical
# 0          ⺀
# 1          ⺈
# ...

# %%
df.fillna(value=' ', limit=1)
# Out:
#      Character                              Definition Pinyin Decomposition  \
# 0            ⺀                                     ice                    ？
# 1            ⺈                                            NaN             ？
# 2            ⺊                                     NaN    NaN           ⿰丨？
# 3            ⺌                                     NaN    NaN             ？
# 4            ⺍                                     NaN    NaN             ？
# ...        ...                                     ...    ...           ...
# 9569         龠             flute; pipe;ancient measure    yuè           ⿱亼？
# 9570         龥                       to beg;to implore     yù           ⿰龠頁
# 9571         龶                                     NaN    NaN             ？
# 9572         龹  Form of 卷 used as a phonetic component   quǎn           ⿻？丿
# 9573         龺           sunlight; the rays of the sun    gān          ⿳十日十
#
#      Radical
# 0          ⺀
# 1          ⺈
# ...

# %%
 df.plot.pie(y='Character', figsize=(8, 4));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.plot.pie(y='Character', figsize=(8, 4))
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
df.dtypes
# Out:
# Character        object
# Definition       object
# Pinyin           object
# Decomposition    object
# Radical          object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      Character                              Definition Pinyin Decomposition  \
# 0            ⺀                                     ice    NaN             ？
# 1            ⺈                                     NaN    NaN             ？
# 2            ⺊                                     NaN    NaN           ⿰丨？
# 3            ⺌                                     NaN    NaN             ？
# 4            ⺍                                     NaN    NaN             ？
# ...        ...                                     ...    ...           ...
# 9569         龠             flute; pipe;ancient measure    yuè           ⿱亼？
# 9570         龥                       to beg;to implore     yù           ⿰龠頁
# 9571         龶                                     NaN    NaN             ？
# 9572         龹  Form of 卷 used as a phonetic component   quǎn           ⿻？丿
# 9573         龺           sunlight; the rays of the sun    gān          ⿳十日十
#
#      Radical
# ...

# %%
df.plot.bar
# Out:
# <bound method PlotAccessor.bar of <pandas.plotting._core.PlotAccessor object at 0x000001C78101B590>>

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36228\1524420410.py in ?()
# ----> 1 plt.pie(df)
#
# ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py in ?(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2795         pctdistance=0.6, shadow=False, labeldistance=1.1,
#    2796         startangle=0, radius=1, counterclock=True, wedgeprops=None,
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
radicalCount = df.Radical.value_counts().reset_index().rename(
           columns={'index': 'Radical', 0: 'count'})

# %%
plt.pie(radicalCount)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36228\452812968.py in ?()
# ----> 1 plt.pie(radicalCount)
#
# ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py in ?(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2795         pctdistance=0.6, shadow=False, labeldistance=1.1,
#    2796         startangle=0, radius=1, counterclock=True, wedgeprops=None,
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
plt.pie(radicalCount["count"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c785b16710>,
# ...
#  [Text(1.086907743553515, 0.16920861976686144, ''),
#   Text(0.991111040519913, 0.4771780646252881, ''),
#   Text(0.8245348147987615, 0.7281087413187486, ''),
#   Text(0.6080671833663539, 0.9166538607963799, ''),
#   Text(0.3726151624199049, 1.0349676037126903, ''),
#   Text(0.15927443368651167, 1.0884078531386299, ''),
#   Text(-0.017352928787549758, 1.0998631168752293, ''),
#   Text(-0.16866710806338456, 1.086991907356046, ''),
#   Text(-0.3023932708209378, 1.057619170477831, ''),
#   Text(-0.42605158795976295, 1.014140051667897, ''),
#   Text(-0.5382521955475247, 0.9593146376389081, ''),
#   Text(-0.6375755256304114, 0.8963801922828867, ''),
#   Text(-0.7266013504542426, 0.8258634738975148, ''),
#   Text(-0.8071375989663178, 0.7473479084970317, ''),
#   Text(-0.8783561233308381, 0.6621861676350705, ''),
#   Text(-0.9387288061010176, 0.5734005830099568, ''),
#   Text(-0.9890415135520851, 0.48145288914970774, ''),
# ...

# %%
radicalCount
# Out:
#                                       Radical  count
# 0                                           氵    465
# 1                                           口    421
# 2                                           艹    406
# 3                                           木    382
# 4                                           扌    341
# ..                                        ...    ...
# 307                                         ⺈      1
# 308                                         歺      1
# 309                              matches:[[1]      1
# 310   building up steam 丷 and letting it off}      1
# 311                                         龶      1
#
# [312 rows x 2 columns]

# %%
count = radicalCount["count"]

# %%
plt.show()

# %%
pie = plt.pie(radicalCount["count"])

# %%
plt.show()

# %%
newCount = radicalCount.nlargest(5, 'count', keep='all')

# %%
plt.pie(newCount["count"], labels = newCount["Radical"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c786ae6bd0>,
# ...
#  [Text(0.8233618203614949, 0.7294349270298247, '氵'),
#   Text(-0.5613473044255062, 0.9459858370050886, '口'),
#   Text(-1.064669577265474, -0.2765478100534469, '艹'),
#   Text(-0.09677300842590891, -1.09573490627989, '木'),
#   Text(0.9481666251338875, -0.557655853535327, '扌')])
# C:\Users\cammi\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 27701 (\N{CJK UNIFIED IDEOGRAPH-6C35}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\cammi\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 21475 (\N{CJK UNIFIED IDEOGRAPH-53E3}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\cammi\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 33401 (\N{CJK UNIFIED IDEOGRAPH-8279}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']

# %%
plt.pie(newCount["count"], labels = newCount["Radical"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c786c78950>,
# ...
#  [Text(0.8233618203614949, 0.7294349270298247, '氵'),
#   Text(-0.5613473044255062, 0.9459858370050886, '口'),
#   Text(-1.064669577265474, -0.2765478100534469, '艹'),
#   Text(-0.09677300842590891, -1.09573490627989, '木'),
#   Text(0.9481666251338875, -0.557655853535327, '扌')])
